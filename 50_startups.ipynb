# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("50_Startups.csv") # importing dataset

# %%
data.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77
# 9  123334.88       108679.17        304981.62  California  149759.96

# %% [markdown]
# EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data.corr() #corelation analysis
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
data1=data.rename({'R&D Spend':'RDS','Administration':'ADM','Marketing Spend':'MKS','Profit':'PRF'},axis=1)

# %%
import seaborn as sns
sns.pairplot(data1)

# %%
# preparing model considering all the variables 
import statsmodels.formula.api as smf # for regression model

# %%
# Preparing model                  
ml1 = smf.ols('PRF~RDS+ADM+MKS',data=data1).fit() # regression model

# %%
ml1.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADM             -0.026816
# MKS              0.027228
# dtype: float64

# %%
ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    PRF   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):           4.53e-30
# Time:                        22:41:48   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %% [markdown]
# p values for ADM and MKS are greater than 0.05 so there is colinearity, Building models for ADM and MKS individually

# %%
ml_A=smf.ols('PRF~ADM',data=data1).fit()

# %%
ml_A.summary() # p>0.05
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    PRF   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):              0.162
# Time:                        22:46:03   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.697e+04   2.53e+04      3.040      0.004    2.61e+04    1.28e+05
# ...

# %%
ml_M=smf.ols('PRF~MKS',data=data1).fit()
ml_M.summary() # p<0.05
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    PRF   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):           4.38e-10
# Time:                        22:48:36   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept       6e+04   7684.530      7.808      0.000    4.46e+04    7.55e+04
# ...

# %%
ml_RM = smf.ols('PRF~ADM+MKS',data=data1).fit() # regression model
ml_RM.summary() #both varials are p<0.05
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    PRF   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     36.71
# Date:                Fri, 11 Feb 2022   Prob (F-statistic):           2.50e-10
# Time:                        22:56:19   Log-Likelihood:                -577.13
# No. Observations:                  50   AIC:                             1160.
# Df Residuals:                      47   BIC:                             1166.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.022e+04   1.77e+04      1.143      0.259   -1.54e+04    5.58e+04
# ...

# %% [markdown]
# Model Validation: Collinerity check, Residual analysis

# %%
#collonearity check
#calculate VIF

rsq_r=smf.ols("RDS~ADM+MKS",data=data1).fit().rsquared
vif_r=1/(1-rsq_r)

rsq_a=smf.ols("ADM~RDS+MKS",data=data1).fit().rsquared
vif_a=1/(1-rsq_a)

rsq_m=smf.ols("MKS~ADM+RDS",data=data1).fit().rsquared
vif_m=1/(1-rsq_m)

d1={'variables':['RDS','ADM','MKS'],'vif':[vif_r,vif_a,vif_m]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   variables       vif
# 0       RDS  2.468903
# 1       ADM  1.175091
# 2       MKS  2.326773

# %%
# none of variable has VIF>20, No collinearity, So considering all variables for model

# %%
# Residual Analysis
# Test for Normality of Residuals (Q-Q plot)

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
sm.qqplot(ml1.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()
# Out:
# C:\Users\Shri\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
list(np.where(ml1.resid<-30000))
# Out:
# [array([49], dtype=int64)]

# %%
# Test for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)
def standard_values(vals) : return (vals-vals.mean())/vals.std()  # User

# %%
from statsmodels.graphics.regressionplots import influence_plot
plt.scatter(standard_values(ml1.fittedvalues),standard_values(ml1.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized residual values')
plt.show()

# %%
# Test for errors or Residuals Vs Regressors or independent 'x' variables or predictors 
# using Residual Regression Plots code graphics.plot_regress_exog(model,'x',fig)    # exog

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(ml1,'RDS',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(ml1,'ADM',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(ml1,'MKS',fig=fig)
plt.show()

# %% [markdown]
# Model Deletion Diagnostics (checking Outliers or Influencers)
#
# Two Techniques : 1. Cook's Distance & 2. Leverage value

# %%
# 1. Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
(c,_)=ml1.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
# Plot the influencers using the stem plot
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(data1)),np.round(c,5))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (49, 0.2880822927543263)

# %%
# 2. Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
influence_plot(ml1)
plt.show()

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=data1.shape[1]
n=data1.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.36

# %%
data1[data1.index.isin([49])]
# Out:
#     RDS       ADM       MKS       State      PRF
# 49  0.0  116983.8  45173.06  California  14681.4

# %% [markdown]
# Improving the Model

# %%
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
data2=data1.drop(data1.index[[49]],axis=0).reset_index(drop=True)
data2
# Out:
#           RDS        ADM        MKS       State        PRF
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# Model Deletion Diagnostics and Final Model

# %%
while np.max(c)>0.5 :
    model=smf.ols("PRF~RDS+ADM+MKS",data=data2).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    data2=data2.drop(data2.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    data2
else:
    final_model=smf.ols("PRF~RDS+ADM+MKS",data=data2).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.9613162435129847

# %%
data2
# Out:
#           RDS        ADM        MKS       State        PRF
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# Model Predictions

# %%
# say New data for prediction is
new_data=pd.DataFrame({'RDS':70000,"ADM":90000,"MKS":140000},index=[0])
new_data
# Out:
#      RDS    ADM     MKS
# 0  70000  90000  140000

# %%
# Manual Prediction of Price
final_model.predict(new_data)
# Out:
# 0    108727.154753
# dtype: float64

# %%
# Automatic Prediction of Price with 90.02% accurcy
pred_y=final_model.predict(data2)
pred_y
# Out:
# 0     190716.676999
# 1     187537.122227
# 2     180575.526396
# 3     172461.144642
# 4     170863.486721
# 5     162582.583177
# 6     157741.338633
# 7     159347.735318
# 8     151328.826941
# 9     154236.846778
# 10    135507.792682
# 11    135472.855621
# 12    129355.599449
# 13    127780.129139
# 14    149295.404796
# 15    145937.941975
# 16    117437.627921
# 17    130408.626295
# 18    129129.234457
# 19    116641.003121
# 20    117097.731866
# 21    117911.019038
# 22    115248.217796
# 23    110603.139045
# 24    114051.073877
# 25    103398.054385
# 26    111547.638935
# 27    114916.165026
# 28    103027.229434
# 29    103057.621761
# 30    100656.410227
# 31     99088.213693
# 32    100325.741335
# 33     98962.303136
# 34     90552.307809
# 35     91709.288672
# 36     77080.554255
# 37     90722.503244
# 38     71433.021956
# 39     85147.375646
# 40     76625.510303
# 41     76492.145175
# 42     72492.394974
# 43     62592.049718
# 44     67025.731107
# ...

# %% [markdown]
# R^2 value for each prepared model

# %%
d2={'Prep_Models':['Ml1','Final_Model'],'Rsquared':[ml1.rsquared,final_model.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#    Prep_Models  Rsquared
# 0          Ml1  0.950746
# 1  Final_Model  0.961316
